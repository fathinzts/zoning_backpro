# %%
import os
from PIL import Image, ImageOps
import pandas as pd 
import cv2
from skimage.feature import greycomatrix, greycoprops

# %%
#Dataset path
dataset_path ={
    '32':
    {
        'train':
         {
             'a': "contoh dataset rizka/32/a",
             'ba': "contoh dataset rizka/32/ba",
             'ca': "contoh dataset rizka/32/ca",
             'da': "contoh dataset rizka/32/da",
             'fa': "contoh dataset rizka/32/fa",
             'ga': "contoh dataset rizka/32/ga",
             'ha': "contoh dataset rizka/32/ha",
             'ja': "contoh dataset rizka/32/ja",
             'ka': "contoh dataset rizka/32/ka",
             'la': "contoh dataset rizka/32/la",
             'ma': "contoh dataset rizka/32/ma",
             'mpa': "contoh dataset rizka/32/mpa",
             'na': "contoh dataset rizka/32/na",
             'nca': "contoh dataset rizka/32/nca",
             'nga': "contoh dataset rizka/32/nga",
             'nta': "contoh dataset rizka/32/nta",
             'pa': "contoh dataset rizka/32/pa",
             'ra': "contoh dataset rizka/32/ra",
             'sa': "contoh dataset rizka/32/sa",
             'ta': "contoh dataset rizka/32/ta",
             'wa': "contoh dataset rizka/32/wa",
             'ya': "contoh dataset rizka/32/ya"
    },
        'test':
            {
        'a': "contoh dataset rizka/32/testing/a",
        'ba': "contoh dataset rizka/32/testing/ba",
        'ca': "contoh dataset rizka/32/testing/ca",
        'da': "contoh dataset rizka/32/testing/da",
        'fa': "contoh dataset rizka/32/testing/fa",
        'ga': "contoh dataset rizka/32/testing/ga",
        'ha': "contoh dataset rizka/32/testing/ha",
        'ja': "contoh dataset rizka/32/testing/ja",
        'ka': "contoh dataset rizka/32/testing/ka",
        'la': "contoh dataset rizka/32/testing/la",
        'ma': "contoh dataset rizka/32/testing/ma",
        'mpa': "contoh dataset rizka/32/testing/mpa",
        'na': "contoh dataset rizka/32/testing/na",
        'nca': "contoh dataset rizka/32/testing/nca",
        'nga': "contoh dataset rizka/32/testing/nga",
        'nta': "contoh dataset rizka/32/testing/nta",
        'pa': "contoh dataset rizka/32/testing/pa",
        'ra': "contoh dataset rizka/32/testing/ra",
        'sa': "contoh dataset rizka/32/testing/sa",
        'ta': "contoh dataset rizka/32/testing/ta",
        'wa': "contoh dataset rizka/32/testing/wa",
        'ya': "contoh dataset rizka/32/testing/ya"
                 
            },
    },
        
    '64':
    {
        'train':
         {
        'a': "contoh dataset rizka/64/a",
        'ba': "contoh dataset rizka/64/ba",
        'ca': "contoh dataset rizka/64/ca",
        'da': "contoh dataset rizka/64/da",
        'fa': "contoh dataset rizka/64/fa",
        'ga': "contoh dataset rizka/64/ga",
        'ha': "contoh dataset rizka/64/ha",
        'ja': "contoh dataset rizka/64/ja",
        'ka': "contoh dataset rizka/64/ka",
        'la': "contoh dataset rizka/64/la",
        'ma': "contoh dataset rizka/64/ma",
        'mpa': "contoh dataset rizka/64/mpa",
        'na': "contoh dataset rizka/64/na",
        'nca': "contoh dataset rizka/64/nca",
        'nga': "contoh dataset rizka/64/nga",
        'nta': "contoh dataset rizka/64/nta",
        'pa': "contoh dataset rizka/64/pa",
        'ra': "contoh dataset rizka/64/ra",
        'sa': "contoh dataset rizka/64/sa",
        'ta': "contoh dataset rizka/64/ta",
        'wa': "contoh dataset rizka/64/wa",
        'ya': "contoh dataset rizka/64/ya"
         },
          'test':
            {
        'a': "contoh dataset rizka/64/testing/a",
        'ba': "contoh dataset rizka/64/testing/ba",
        'ca': "contoh dataset rizka/64/testing/ca",
        'da': "contoh dataset rizka/64/testing/da",
        'fa': "contoh dataset rizka/64/testing/fa",
        'ga': "contoh dataset rizka/64/testing/ga",
        'ha': "contoh dataset rizka/64/testing/ha",
        'ja': "contoh dataset rizka/64/testing/ja",
        'ka': "contoh dataset rizka/64/testing/ka",
        'la': "contoh dataset rizka/64/testing/la",
        'ma': "contoh dataset rizka/64/testing/ma",
        'mpa': "contoh dataset rizka/64/testing/mpa",
        'na': "contoh dataset rizka/64/testing/na",
        'nca': "contoh dataset rizka/64/testing/nca",
        'nga': "contoh dataset rizka/64/testing/nga",
        'nta': "contoh dataset rizka/64/testing/nta",
        'pa': "contoh dataset rizka/64/testing/pa",
        'ra': "contoh dataset rizka/64/testing/ra",
        'sa': "contoh dataset rizka/64/testing/sa",
        'ta': "contoh dataset rizka/64/testing/ta",
        'wa': "contoh dataset rizka/64/testing/wa",
        'ya': "contoh dataset rizka/64/testing/ya"
            },
         },
    '128':
    { 'train':
        {
        'a': "contoh dataset rizka/128/a",
        'ba': "contoh dataset rizka/128/ba",
        'ca': "contoh dataset rizka/128/ca",
        'da': "contoh dataset rizka/128/da",
        'fa': "contoh dataset rizka/128/fa",
        'ga': "contoh dataset rizka/128/ga",
        'ha': "contoh dataset rizka/128/ha",
        'ja': "contoh dataset rizka/128/ja",
        'ka': "contoh dataset rizka/128/ka",
        'la': "contoh dataset rizka/128/la",
        'ma': "contoh dataset rizka/128/ma",
        'mpa': "contoh dataset rizka/128/mpa",
        'na': "contoh dataset rizka/128/na",
        'nca': "contoh dataset rizka/128/nca",
        'nga': "contoh dataset rizka/128/nga",
        'nta': "contoh dataset rizka/128/nta",
        'pa': "contoh dataset rizka/128/pa",
        'ra': "contoh dataset rizka/128/ra",
        'sa': "contoh dataset rizka/128/sa",
        'ta': "contoh dataset rizka/128/ta",
        'wa': "contoh dataset rizka/128/wa",
        'ya': "contoh dataset rizka/128/ya"
    },
     
     'test':
      {
       'a': "contoh dataset rizka/128/testing/a",
        'ba': "contoh dataset rizka/128/testing/ba",
        'ca': "contoh dataset rizka/128/testing/ca",
        'da': "contoh dataset rizka/128/testing/da",
        'fa': "contoh dataset rizka/128/testing/fa",
        'ga': "contoh dataset rizka/128/testing/ga",
        'ha': "contoh dataset rizka/128/testing/ha",
        'ja': "contoh dataset rizka/128/testing/ja",
        'ka': "contoh dataset rizka/128/testing/ka",
        'la': "contoh dataset rizka/128/testing/la",
        'ma': "contoh dataset rizka/128/testing/ma",
        'mpa': "contoh dataset rizka/128/testing/mpa",
        'na': "contoh dataset rizka/128/testing/na",
        'nca': "contoh dataset rizka/128/testing/nca",
        'nga': "contoh dataset rizka/128/testing/nga",
        'nta': "contoh dataset rizka/128/testing/nta",
        'pa': "contoh dataset rizka/128/testing/pa",
        'ra': "contoh dataset rizka/128/testing/ra",
        'sa': "contoh dataset rizka/128/testing/sa",
        'ta': "contoh dataset rizka/128/testing/ta",
        'wa': "contoh dataset rizka/128/testing/wa",
        'ya': "contoh dataset rizka/128/testing/ya"}
         
     }
}

# %% [markdown]
# Preprocessing

# %%
#1. Cropping (Manual)

# %%
#2. Resize
#32x32
def Resize32(images_folder_path):
    for filename in os.listdir(images_folder_path):
        newimg = os.path.join(images_folder_path, filename)
        img = Image.open(newimg)
        img = img.resize((32,32))
        img.save(newimg)
#64x64
def Resize64(images_folder_path):
    for filename in os.listdir(images_folder_path):
        newimg = os.path.join(images_folder_path, filename)
        img = Image.open(newimg)
        img = img.resize((64,64))
        img.save(newimg)
#128x128
def Resize128(images_folder_path):
    for filename in os.listdir(images_folder_path):
        newimg = os.path.join(images_folder_path, filename)
        img = Image.open(newimg)
        img = img.resize((128,128))
        img.save(newimg)

# %%
Resize32(dataset_path['32']['train']['a'])
Resize32(dataset_path['32']['train']['ba'])
Resize32(dataset_path['32']['train']['ca'])
Resize32(dataset_path['32']['train']['da'])
Resize32(dataset_path['32']['train']['fa'])
Resize32(dataset_path['32']['train']['ga'])
Resize32(dataset_path['32']['train']['ha'])
Resize32(dataset_path['32']['train']['ja'])
Resize32(dataset_path['32']['train']['ka'])
Resize32(dataset_path['32']['train']['la'])
Resize32(dataset_path['32']['train']['ma'])
Resize32(dataset_path['32']['train']['mpa'])
Resize32(dataset_path['32']['train']['na'])
Resize32(dataset_path['32']['train']['nca'])
Resize32(dataset_path['32']['train']['nga'])
Resize32(dataset_path['32']['train']['nta'])
Resize32(dataset_path['32']['train']['pa'])
Resize32(dataset_path['32']['train']['ra'])
Resize32(dataset_path['32']['train']['sa'])
Resize32(dataset_path['32']['train']['ta'])
Resize32(dataset_path['32']['train']['wa'])
Resize32(dataset_path['32']['train']['ya'])

Resize32(dataset_path['32']['test']['a'])
Resize32(dataset_path['32']['test']['ba'])
Resize32(dataset_path['32']['test']['ca'])
Resize32(dataset_path['32']['test']['da'])
Resize32(dataset_path['32']['test']['fa'])
Resize32(dataset_path['32']['test']['ga'])
Resize32(dataset_path['32']['test']['ha'])
Resize32(dataset_path['32']['test']['ja'])
Resize32(dataset_path['32']['test']['ka'])
Resize32(dataset_path['32']['test']['la'])
Resize32(dataset_path['32']['test']['ma'])
Resize32(dataset_path['32']['test']['mpa'])
Resize32(dataset_path['32']['test']['na'])
Resize32(dataset_path['32']['test']['nca'])
Resize32(dataset_path['32']['test']['nga'])
Resize32(dataset_path['32']['test']['nta'])
Resize32(dataset_path['32']['test']['pa'])
Resize32(dataset_path['32']['test']['ra'])
Resize32(dataset_path['32']['test']['sa'])
Resize32(dataset_path['32']['test']['ta'])
Resize32(dataset_path['32']['test']['wa'])
Resize32(dataset_path['32']['test']['ya'])

# %%
Resize64(dataset_path['64']['train']['a'])
Resize64(dataset_path['64']['train']['ba'])
Resize64(dataset_path['64']['train']['ca'])
Resize64(dataset_path['64']['train']['da'])
Resize64(dataset_path['64']['train']['fa'])
Resize64(dataset_path['64']['train']['ga'])
Resize64(dataset_path['64']['train']['ha'])
Resize64(dataset_path['64']['train']['ja'])
Resize64(dataset_path['64']['train']['ka'])
Resize64(dataset_path['64']['train']['la'])
Resize64(dataset_path['64']['train']['ma'])
Resize64(dataset_path['64']['train']['mpa'])
Resize64(dataset_path['64']['train']['na'])
Resize64(dataset_path['64']['train']['nca'])
Resize64(dataset_path['64']['train']['nga'])
Resize64(dataset_path['64']['train']['nta'])
Resize64(dataset_path['64']['train']['pa'])
Resize64(dataset_path['64']['train']['ra'])
Resize64(dataset_path['64']['train']['sa'])
Resize64(dataset_path['64']['train']['ta'])
Resize64(dataset_path['64']['train']['wa'])
Resize64(dataset_path['64']['train']['ya'])

Resize64(dataset_path['64']['test']['a'])
Resize64(dataset_path['64']['test']['ba'])
Resize64(dataset_path['64']['test']['ca'])
Resize64(dataset_path['64']['test']['da'])
Resize64(dataset_path['64']['test']['fa'])
Resize64(dataset_path['64']['test']['ga'])
Resize64(dataset_path['64']['test']['ha'])
Resize64(dataset_path['64']['test']['ja'])
Resize64(dataset_path['64']['test']['ka'])
Resize64(dataset_path['64']['test']['la'])
Resize64(dataset_path['64']['test']['ma'])
Resize64(dataset_path['64']['test']['mpa'])
Resize64(dataset_path['64']['test']['na'])
Resize64(dataset_path['64']['test']['nca'])
Resize64(dataset_path['64']['test']['nga'])
Resize64(dataset_path['64']['test']['nta'])
Resize64(dataset_path['64']['test']['pa'])
Resize64(dataset_path['64']['test']['ra'])
Resize64(dataset_path['64']['test']['sa'])
Resize64(dataset_path['64']['test']['ta'])
Resize64(dataset_path['64']['test']['wa'])
Resize64(dataset_path['64']['test']['ya'])

# %%
Resize128(dataset_path['128']['train']['a'])
Resize128(dataset_path['128']['train']['ba'])
Resize128(dataset_path['128']['train']['ca'])
Resize128(dataset_path['128']['train']['da'])
Resize128(dataset_path['128']['train']['fa'])
Resize128(dataset_path['128']['train']['ga'])
Resize128(dataset_path['128']['train']['ha'])
Resize128(dataset_path['128']['train']['ja'])
Resize128(dataset_path['128']['train']['ka'])
Resize128(dataset_path['128']['train']['la'])
Resize128(dataset_path['128']['train']['ma'])
Resize128(dataset_path['128']['train']['mpa'])
Resize128(dataset_path['128']['train']['na'])
Resize128(dataset_path['128']['train']['nca'])
Resize128(dataset_path['128']['train']['nga'])
Resize128(dataset_path['128']['train']['nta'])
Resize128(dataset_path['128']['train']['pa'])
Resize128(dataset_path['128']['train']['ra'])
Resize128(dataset_path['128']['train']['sa'])
Resize128(dataset_path['128']['train']['ta'])
Resize128(dataset_path['128']['train']['wa'])
Resize128(dataset_path['128']['train']['ya'])

Resize128(dataset_path['128']['test']['a'])
Resize128(dataset_path['128']['test']['ba'])
Resize128(dataset_path['128']['test']['ca'])
Resize128(dataset_path['128']['test']['da'])
Resize128(dataset_path['128']['test']['fa'])
Resize128(dataset_path['128']['test']['ga'])
Resize128(dataset_path['128']['test']['ha'])
Resize128(dataset_path['128']['test']['ja'])
Resize128(dataset_path['128']['test']['ka'])
Resize128(dataset_path['128']['test']['la'])
Resize128(dataset_path['128']['test']['ma'])
Resize128(dataset_path['128']['test']['mpa'])
Resize128(dataset_path['128']['test']['na'])
Resize128(dataset_path['128']['test']['nca'])
Resize128(dataset_path['128']['test']['nga'])
Resize128(dataset_path['128']['test']['nta'])
Resize128(dataset_path['128']['test']['pa'])
Resize128(dataset_path['128']['test']['ra'])
Resize128(dataset_path['128']['test']['sa'])
Resize128(dataset_path['128']['test']['ta'])
Resize128(dataset_path['128']['test']['wa'])
Resize128(dataset_path['128']['test']['ya'])

# %%
#3. Convert to GRAYSCALE
def Grayscale(img):
    fGr = img[:,:,0]
    fgr = np.mean(np.mean(fGr))
    abu=fgr/255
    return abu

# %%
def Biner(images_folder_path):
    for filename in os.listdir(images_folder_path):
        newimg = os.path.join(images_folder_path, filename)
        img = cv2.imread(newimg,cv2.IMREAD_GRAYSCALE)
        (thresh, im_bw) = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
        thresh = 127
        im_bw = cv2.threshold(img, thresh, 255, cv2.THRESH_BINARY)[1]
        cv2.imwrite(newimg,im_bw)

# %%
Biner(dataset_path['32']['train']['a'])
Biner(dataset_path['32']['train']['ba'])
Biner(dataset_path['32']['train']['ca'])
Biner(dataset_path['32']['train']['da'])
Biner(dataset_path['32']['train']['fa'])
Biner(dataset_path['32']['train']['ga'])
Biner(dataset_path['32']['train']['ha'])
Biner(dataset_path['32']['train']['ja'])
Biner(dataset_path['32']['train']['ka'])
Biner(dataset_path['32']['train']['la'])
Biner(dataset_path['32']['train']['ma'])
Biner(dataset_path['32']['train']['mpa'])
Biner(dataset_path['32']['train']['na'])
Biner(dataset_path['32']['train']['nca'])
Biner(dataset_path['32']['train']['nga'])
Biner(dataset_path['32']['train']['nta'])
Biner(dataset_path['32']['train']['pa'])
Biner(dataset_path['32']['train']['ra'])
Biner(dataset_path['32']['train']['sa'])
Biner(dataset_path['32']['train']['ta'])
Biner(dataset_path['32']['train']['wa'])
Biner(dataset_path['32']['train']['ya'])

Biner(dataset_path['32']['test']['a'])
Biner(dataset_path['32']['test']['ba'])
Biner(dataset_path['32']['test']['ca'])
Biner(dataset_path['32']['test']['da'])
Biner(dataset_path['32']['test']['fa'])
Biner(dataset_path['32']['test']['ga'])
Biner(dataset_path['32']['test']['ha'])
Biner(dataset_path['32']['test']['ja'])
Biner(dataset_path['32']['test']['ka'])
Biner(dataset_path['32']['test']['la'])
Biner(dataset_path['32']['test']['ma'])
Biner(dataset_path['32']['test']['mpa'])
Biner(dataset_path['32']['test']['na'])
Biner(dataset_path['32']['test']['nca'])
Biner(dataset_path['32']['test']['nga'])
Biner(dataset_path['32']['test']['nta'])
Biner(dataset_path['32']['test']['pa'])
Biner(dataset_path['32']['test']['ra'])
Biner(dataset_path['32']['test']['sa'])
Biner(dataset_path['32']['test']['ta'])
Biner(dataset_path['32']['test']['wa'])
Biner(dataset_path['32']['test']['ya'])

# %%
Biner(dataset_path['64']['train']['a'])
Biner(dataset_path['64']['train']['ba'])
Biner(dataset_path['64']['train']['ca'])
Biner(dataset_path['64']['train']['fa'])
Biner(dataset_path['64']['train']['ga'])
Biner(dataset_path['64']['train']['ha'])
Biner(dataset_path['64']['train']['ja'])
Biner(dataset_path['64']['train']['ka'])
Biner(dataset_path['64']['train']['la'])
Biner(dataset_path['64']['train']['ma'])
Biner(dataset_path['64']['train']['mpa'])
Biner(dataset_path['64']['train']['na'])
Biner(dataset_path['64']['train']['nca'])
Biner(dataset_path['64']['train']['nga'])
Biner(dataset_path['64']['train']['nta'])
Biner(dataset_path['64']['train']['pa'])
Biner(dataset_path['64']['train']['ra'])
Biner(dataset_path['64']['train']['sa'])
Biner(dataset_path['64']['train']['ta'])
Biner(dataset_path['64']['train']['wa'])
Biner(dataset_path['64']['train']['ya'])

Biner(dataset_path['64']['test']['a'])
Biner(dataset_path['64']['test']['ba'])
Biner(dataset_path['64']['test']['ca'])
Biner(dataset_path['64']['test']['fa'])
Biner(dataset_path['64']['test']['ga'])
Biner(dataset_path['64']['test']['ha'])
Biner(dataset_path['64']['test']['ja'])
Biner(dataset_path['64']['test']['ka'])
Biner(dataset_path['64']['test']['la'])
Biner(dataset_path['64']['test']['ma'])
Biner(dataset_path['64']['test']['mpa'])
Biner(dataset_path['64']['test']['na'])
Biner(dataset_path['64']['test']['nca'])
Biner(dataset_path['64']['test']['nga'])
Biner(dataset_path['64']['test']['nta'])
Biner(dataset_path['64']['test']['pa'])
Biner(dataset_path['64']['test']['ra'])
Biner(dataset_path['64']['test']['sa'])
Biner(dataset_path['64']['test']['ta'])
Biner(dataset_path['64']['test']['wa'])
Biner(dataset_path['64']['test']['ya'])

# %%
Biner(dataset_path['128']['train']['a'])
Biner(dataset_path['128']['train']['ba'])
Biner(dataset_path['128']['train']['ca'])
Biner(dataset_path['128']['train']['fa'])
Biner(dataset_path['128']['train']['ga'])
Biner(dataset_path['128']['train']['ha'])
Biner(dataset_path['128']['train']['ja'])
Biner(dataset_path['128']['train']['ka'])
Biner(dataset_path['128']['train']['la'])
Biner(dataset_path['128']['train']['ma'])
Biner(dataset_path['128']['train']['mpa'])
Biner(dataset_path['128']['train']['na'])
Biner(dataset_path['128']['train']['nca'])
Biner(dataset_path['128']['train']['nga'])
Biner(dataset_path['128']['train']['nta'])
Biner(dataset_path['128']['train']['pa'])
Biner(dataset_path['128']['train']['ra'])
Biner(dataset_path['128']['train']['sa'])
Biner(dataset_path['128']['train']['ta'])
Biner(dataset_path['128']['train']['wa'])
Biner(dataset_path['128']['train']['ya'])

Biner(dataset_path['128']['test']['a'])
Biner(dataset_path['128']['test']['ba'])
Biner(dataset_path['128']['test']['ca'])
Biner(dataset_path['128']['test']['fa'])
Biner(dataset_path['128']['test']['ga'])
Biner(dataset_path['128']['test']['ha'])
Biner(dataset_path['128']['test']['ja'])
Biner(dataset_path['128']['test']['ka'])
Biner(dataset_path['128']['test']['la'])
Biner(dataset_path['128']['test']['ma'])
Biner(dataset_path['128']['test']['mpa'])
Biner(dataset_path['128']['test']['na'])
Biner(dataset_path['128']['test']['nca'])
Biner(dataset_path['128']['test']['nga'])
Biner(dataset_path['128']['test']['nta'])
Biner(dataset_path['128']['test']['pa'])
Biner(dataset_path['128']['test']['ra'])
Biner(dataset_path['128']['test']['sa'])
Biner(dataset_path['128']['test']['ta'])
Biner(dataset_path['128']['test']['wa'])
Biner(dataset_path['128']['test']['ya'])

# %% [markdown]
# Ekstraksi Fitur

# %%
from scipy.spatial import distance
a = (1, 2, 3)
b = (4, 5, 6)

print(distance.euclidean(a, b))
# Out:
# 5.196152422706632

# %%
A = np.array([   
    [1, 0, 0, 0],
    [1, 1, 0, 0],
    [1, 0, 1, 1],
    [1, 0, 1, 1],
])

# %%
from scipy.spatial import distance
import numpy as np
def zoning(dataset):
    a,b = np.shape(dataset)
    matriks = np.zeros((np.max(dataset)+1, np.max(dataset)+1))
    xc=0
    yc=0
    for i in range(a):
        for j in range(b):
            if matriks[dataset[i][j]]=='1':
                xc=j
                xc=+j
#               return xc
#             else:
                xc=j
                xc=+j
# #                 return yc
    for i in range(a):
        for j in range(b):
            matriks[dataset[i][j]]=distance.euclidean(xc,yc)

# %%
def getBinerValue(images_folder_path):
    for filename in os.listdir(images_folder_path):
        img = cv2.imread(filename,0)
        for i in range(img.shape[0]):
            for j in range(img.shape[1]):
                print(img[i][j])

# %%
getBinerValue(dataset_path['128']['test']['ya'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-30ec7acda558> in <module>
# ----> 1 getBinerValue(dataset_path['128']['test']['ya'])
#
# <ipython-input-42-92f78dd046ce> in getBinerValue(images_folder_path)
#       2     for filename in os.listdir(images_folder_path):
#       3         img = cv2.imread(filename,0)
# ----> 4         for i in range(img.shape[0]):
#       5             for j in range(img.shape[1]):
#       6                 print(img[i][j])
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
zoning(dataset_path['128']['test']['ya'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-765137e643e5> in <module>
# ----> 1 zoning(dataset_path['128']['test']['ya'])
#
# <ipython-input-21-bd5e0b381487> in zoning(dataset)
#       2 import numpy as np
#       3 def zoning(dataset):
# ----> 4     a,b = np.shape(dataset)
#       5     matriks = np.zeros((np.max(dataset)+1, np.max(dataset)+1))
#       6     xc=0
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
zoning_size = (6,6)

# %%
def zoning(image, size):
    sub_images = []
    image_shape = image.shape
    image_range = int(image_shape[0]/zoning_size[0])
    for i in range(0, image_shape[0], image_range):
        for j in range (0, image_shape[1], image_range):
            sub_images.append(image[i:i+image_range, j:j+image_range])
    return sub_images

# %%
zoning_images = []

# %%
def CreateDataFrame():
    return {
        'zoning_images' : []
    }
dataframe = CreateDataFrame()

# %%
for image in os.listdir(dataset_path):
    filename2 = filename
    filename = os.path.join(dataset_path, filename)
    img = cv2.imread(filename, 0)
#     dataframe['filename'].append(filename2)
    dataframe['contrast_00'].append(Contrast(NormalizeGLCM(GLCM00(img))))
